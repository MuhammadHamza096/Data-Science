# %%
import pandas as pd 
# data=pd.read_csv('/content/drive/My Drive/Deep Learning /nyc_uber_2014.csv')
# uber1=data.iloc[0:99]
# uber2=data.iloc[99:198]
# uber3=data.iloc[198:]

# row_concat=pd.concat([uber1,uber2,uber3],axis=1)
# print(row_concat)
import re 
data=pd.read_csv('/content/drive/My Drive/Deep Learning /tips.csv')
# print(data.head(50))
data.sex=data.sex.astype('category')
# data.smoker=data.smoker.astype('category')
# # print(data.info())
# data.total_bill=pd.to_numeric(data['total_bill'])


# data.tip=pd.to_numeric(data['tip'])
# print(data.info())
# prog=re.compile('\d{3}-\d{3}-\d{4}')
# result=prog.findall('hellow hajhjadl 123-098-4444')
# print(result)
# val='-POI-123876 ,GM-1249 POI-13321 '
# fi=re.compile('POI-\d*')
# result=fi.findall(val)
# print(result)

# val="the recipe calls for 10 strawberries and 1 banana"
# fi=re.compile('\d+')
# result=fi.findall(val)
# print(result)
import numpy as np
def sex_record(sex_value):
  if sex_value=='Male':
    return 1
  elif  sex_value=='Female':
    return 0
  else:
    return np.nan

data['sex_record']=data.sex.apply(sex_record)
print(data.head())

# remove duplicates values
student=[{'Name:hamza',}]
# Out:
#    total_bill   tip     sex smoker  day    time  size sex_record
# 0       16.99  1.01  Female     No  Sun  Dinner     2          0
# 1       10.34  1.66    Male     No  Sun  Dinner     3          1
# 2       21.01  3.50    Male     No  Sun  Dinner     3          1
# 3       23.68  3.31    Male     No  Sun  Dinner     2          1
# 4       24.59  3.61  Female     No  Sun  Dinner     4          0

# %%
from google.colab import drive
drive.mount('/content/drive')
